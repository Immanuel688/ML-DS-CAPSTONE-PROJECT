# %%
import pandas as pd

# %%
import numpy as np

# %%
pre_dataset= pd.read_csv("Preprocessed_dataset.csv")
pre_dataset
# Out:
#       Age  Gender  Income CampaignChannel   CampaignType      AdSpend  \
# 0      56  Female  136912    Social Media      Awareness  6497.870068
# 1      69    Male   41760           Email      Retention  3898.668606
# 2      46  Female   88456             PPC      Awareness  1546.429596
# 3      32  Female   44085             PPC     Conversion   539.525936
# 4      60  Female   83964             PPC     Conversion  1678.043573
# ...   ...     ...     ...             ...            ...          ...
# 7995   21    Male   24849           Email      Awareness  8518.308575
# 7996   43  Female   44718             SEO      Retention  1424.613446
# 7997   28  Female  125471        Referral  Consideration  4609.534635
# 7998   19  Female  107862             PPC  Consideration  9476.106354
# 7999   31  Female   93002           Email      Awareness  7743.627070
#
#       ClickThroughRate  ConversionRate  WebsiteVisits  PagesPerVisit  \
# 0             0.043919        0.088031              0       2.399017
# 1             0.155725        0.182725             42       2.917138
# 2             0.277490        0.076423              2       8.223619
# 3             0.137611        0.088004             47       4.540939
# 4             0.252851        0.109940              0       2.046847
# ...                ...             ...            ...            ...
# 7995          0.243792        0.116773             23       9.693602
# 7996          0.236740        0.190061             49       9.499010
# 7997          0.056526        0.133826             35       2.853241
# 7998          0.023961        0.138386             49       1.002964
# 7999          0.185670        0.057228             15       6.964739
#
#       TimeOnSite  SocialShares  EmailOpens  EmailClicks  PreviousPurchases  \
# 0       7.396803            19           6            9                  4
# 1       5.352549             5           2            7                  2
# 2      13.794901             0          11            2                  8
# 3      14.688363            89           2            2                  0
# 4      13.993370             6           6            6                  8
# ...          ...           ...         ...          ...                ...
# 7995   14.227794            70          13            6                  7
# 7996    3.501106            52          13            1                  5
# 7997   14.618323            38          16            0                  3
# 7998    3.876623            86           1            5                  7
# 7999   12.763660             2          18            9                  9
#
#       LoyaltyPoints  Conversion
# 0               688           1
# 1              3459           1
# 2              2337           1
# 3              2463           1
# 4              4345           1
# ...             ...         ...
# 7995            286           0
# 7996           1502           0
# 7997            738           1
# 7998           2709           1
# 7999            341           0
#
# [8000 rows x 17 columns]

# %%
pre_dataset.describe()
# Out:
#                Age         Income      AdSpend  ClickThroughRate  \
# count  8000.000000    8000.000000  8000.000000       8000.000000
# mean     43.625500   84664.196750  5000.944830          0.154829
# std      14.902785   37580.387945  2838.038153          0.084007
# min      18.000000   20014.000000   100.054813          0.010005
# 25%      31.000000   51744.500000  2523.221165          0.082635
# 50%      43.000000   84926.500000  5013.440044          0.154505
# 75%      56.000000  116815.750000  7407.989369          0.228207
# max      69.000000  149986.000000  9997.914781          0.299968
#
#        ConversionRate  WebsiteVisits  PagesPerVisit   TimeOnSite  \
# count     8000.000000    8000.000000    8000.000000  8000.000000
# mean         0.104389      24.751625       5.549299     7.727718
# std          0.054878      14.312269       2.607358     4.228218
# min          0.010018       0.000000       1.000428     0.501669
# 25%          0.056410      13.000000       3.302479     4.068340
# 50%          0.104046      25.000000       5.534257     7.682956
# 75%          0.152077      37.000000       7.835756    11.481468
# max          0.199995      49.000000       9.999055    14.995311
#
#        SocialShares   EmailOpens  EmailClicks  PreviousPurchases  \
# count   8000.000000  8000.000000  8000.000000        8000.000000
# mean      49.799750     9.476875     4.467375           4.485500
# std       28.901165     5.711111     2.856564           2.888093
# min        0.000000     0.000000     0.000000           0.000000
# 25%       25.000000     5.000000     2.000000           2.000000
# 50%       50.000000     9.000000     4.000000           4.000000
# 75%       75.000000    14.000000     7.000000           7.000000
# max       99.000000    19.000000     9.000000           9.000000
#
#        LoyaltyPoints   Conversion
# count    8000.000000  8000.000000
# mean     2490.268500     0.876500
# std      1429.527162     0.329031
# min         0.000000     0.000000
# 25%      1254.750000     1.000000
# 50%      2497.000000     1.000000
# 75%      3702.250000     1.000000
# max      4999.000000     1.000000

# %%
pre_dataset.describe().columns
# Out:
# Index(['Age', 'Income', 'AdSpend', 'ClickThroughRate', 'ConversionRate',
#        'WebsiteVisits', 'PagesPerVisit', 'TimeOnSite', 'SocialShares',
#        'EmailOpens', 'EmailClicks', 'PreviousPurchases', 'LoyaltyPoints',
#        'Conversion'],
#       dtype='object')

# %%
quan = []
quan.extend(pre_dataset.describe().columns)

# %%
quan
# Out:
# ['Age',
#  'Income',
#  'AdSpend',
#  'ClickThroughRate',
#  'ConversionRate',
#  'WebsiteVisits',
#  'PagesPerVisit',
#  'TimeOnSite',
#  'SocialShares',
#  'EmailOpens',
#  'EmailClicks',
#  'PreviousPurchases',
#  'LoyaltyPoints',
#  'Conversion']

# %%
analysis= pd.DataFrame(index=['mean', 'median','mode','Q1:25th', 'Q2:50th','Q3:75th','Q4:100th','min','max','IQR','1.5 Rule','Lesser range','Greater range'], columns=quan)

# %%
analysis
# Out:
#                Age Income AdSpend ClickThroughRate ConversionRate  \
# mean           NaN    NaN     NaN              NaN            NaN
# median         NaN    NaN     NaN              NaN            NaN
# mode           NaN    NaN     NaN              NaN            NaN
# Q1:25th        NaN    NaN     NaN              NaN            NaN
# Q2:50th        NaN    NaN     NaN              NaN            NaN
# Q3:75th        NaN    NaN     NaN              NaN            NaN
# Q4:100th       NaN    NaN     NaN              NaN            NaN
# min            NaN    NaN     NaN              NaN            NaN
# max            NaN    NaN     NaN              NaN            NaN
# IQR            NaN    NaN     NaN              NaN            NaN
# 1.5 Rule       NaN    NaN     NaN              NaN            NaN
# Lesser range   NaN    NaN     NaN              NaN            NaN
# Greater range  NaN    NaN     NaN              NaN            NaN
#
#               WebsiteVisits PagesPerVisit TimeOnSite SocialShares EmailOpens  \
# mean                    NaN           NaN        NaN          NaN        NaN
# median                  NaN           NaN        NaN          NaN        NaN
# mode                    NaN           NaN        NaN          NaN        NaN
# Q1:25th                 NaN           NaN        NaN          NaN        NaN
# Q2:50th                 NaN           NaN        NaN          NaN        NaN
# Q3:75th                 NaN           NaN        NaN          NaN        NaN
# Q4:100th                NaN           NaN        NaN          NaN        NaN
# min                     NaN           NaN        NaN          NaN        NaN
# max                     NaN           NaN        NaN          NaN        NaN
# IQR                     NaN           NaN        NaN          NaN        NaN
# 1.5 Rule                NaN           NaN        NaN          NaN        NaN
# Lesser range            NaN           NaN        NaN          NaN        NaN
# Greater range           NaN           NaN        NaN          NaN        NaN
#
#               EmailClicks PreviousPurchases LoyaltyPoints Conversion
# mean                  NaN               NaN           NaN        NaN
# median                NaN               NaN           NaN        NaN
# mode                  NaN               NaN           NaN        NaN
# Q1:25th               NaN               NaN           NaN        NaN
# Q2:50th               NaN               NaN           NaN        NaN
# Q3:75th               NaN               NaN           NaN        NaN
# Q4:100th              NaN               NaN           NaN        NaN
# min                   NaN               NaN           NaN        NaN
# max                   NaN               NaN           NaN        NaN
# IQR                   NaN               NaN           NaN        NaN
# 1.5 Rule              NaN               NaN           NaN        NaN
# Lesser range          NaN               NaN           NaN        NaN
# Greater range         NaN               NaN           NaN        NaN

# %%
for columnName in quan:
    analysis.loc['mean',columnName]= pre_dataset[columnName].mean()
    analysis.loc['median',columnName]=pre_dataset[columnName].median()
    analysis.loc['mode',columnName]=pre_dataset[columnName].mode()[0]
    analysis.loc['Q1:25th',columnName]=np.percentile(pre_dataset[columnName],25)
    analysis.loc['Q2:50th',columnName]=np.percentile(pre_dataset[columnName],50)
    analysis.loc['Q3:75th',columnName]=np.percentile(pre_dataset[columnName],75)
    analysis.loc['Q4:100th',columnName]=np.percentile(pre_dataset[columnName],100)
    analysis.loc['min',columnName]=pre_dataset[columnName].min()
    analysis.loc['max',columnName]=pre_dataset[columnName].max()
    analysis.loc['IQR',columnName]=analysis.loc['Q3:75th',columnName]-analysis.loc['Q1:25th',columnName]
    analysis.loc['1.5 Rule',columnName]= 1.5*analysis.loc['IQR',columnName]
    analysis.loc['Lesser range', columnName]= analysis.loc['Q1:25th',columnName]- analysis.loc['1.5 Rule',columnName]
    analysis.loc['Greater range', columnName]= analysis.loc['Q3:75th',columnName]+ analysis.loc['1.5 Rule',columnName]

# %%
analysis
# Out:
#                    Age       Income       AdSpend ClickThroughRate  \
# mean           43.6255  84664.19675    5000.94483         0.154829
# median            43.0      84926.5   5013.440044         0.154505
# mode                64        50268    100.054813         0.010005
# Q1:25th           31.0      51744.5   2523.221165         0.082635
# Q2:50th           43.0      84926.5   5013.440044         0.154505
# Q3:75th           56.0    116815.75   7407.989369         0.228207
# Q4:100th          69.0     149986.0   9997.914781         0.299968
# min                 18        20014    100.054813         0.010005
# max                 69       149986   9997.914781         0.299968
# IQR               25.0     65071.25   4884.768205         0.145572
# 1.5 Rule          37.5    97606.875   7327.152307         0.218358
# Lesser range      -6.5   -45862.375  -4803.931142        -0.135723
# Greater range     93.5   214422.625  14735.141676         0.446565
#
#               ConversionRate WebsiteVisits PagesPerVisit TimeOnSite  \
# mean                0.104389     24.751625      5.549299   7.727718
# median              0.104046          25.0      5.534257   7.682956
# mode                0.010018            25      1.000428   0.501669
# Q1:25th              0.05641          13.0      3.302479    4.06834
# Q2:50th             0.104046          25.0      5.534257   7.682956
# Q3:75th             0.152077          37.0      7.835756  11.481468
# Q4:100th            0.199995          49.0      9.999055  14.995311
# min                 0.010018             0      1.000428   0.501669
# max                 0.199995            49      9.999055  14.995311
# IQR                 0.095667          24.0      4.533277   7.413128
# 1.5 Rule            0.143501          36.0      6.799915  11.119693
# Lesser range       -0.087092         -23.0     -3.497436  -7.051353
# Greater range       0.295578          73.0     14.635671  22.601161
#
#               SocialShares EmailOpens EmailClicks PreviousPurchases  \
# mean              49.79975   9.476875    4.467375            4.4855
# median                50.0        9.0         4.0               4.0
# mode                    61          9           4                 0
# Q1:25th               25.0        5.0         2.0               2.0
# Q2:50th               50.0        9.0         4.0               4.0
# Q3:75th               75.0       14.0         7.0               7.0
# Q4:100th              99.0       19.0         9.0               9.0
# min                      0          0           0                 0
# max                     99         19           9                 9
# IQR                   50.0        9.0         5.0               5.0
# 1.5 Rule              75.0       13.5         7.5               7.5
# Lesser range         -50.0       -8.5        -5.5              -5.5
# Greater range        150.0       27.5        14.5              14.5
#
#               LoyaltyPoints Conversion
# mean              2490.2685     0.8765
# median               2497.0        1.0
# mode                   1392          1
# Q1:25th             1254.75        1.0
# Q2:50th              2497.0        1.0
# Q3:75th             3702.25        1.0
# Q4:100th             4999.0        1.0
# min                       0          0
# max                    4999          1
# IQR                  2447.5        0.0
# 1.5 Rule            3671.25        0.0
# Lesser range        -2416.5        1.0
# Greater range        7373.5        1.0

# %%
# Checking for outliers
def find_outiers(analysis,quan):
    greater=[]
    lesser=[]
    for columnName in quan:
        if (analysis.loc['min',columnName]<analysis.loc['Lesser range', columnName]):
            lesser.append(columnName)
        if (analysis.loc['max',columnName]>analysis.loc['Greater range', columnName]): 
            greater.append(columnName)
    return greater, lesser

# %%
greater,lesser= find_outiers(analysis,quan)

# %%
greater
# Out:
# []

# %%
lesser
# Out:
# ['Conversion']

# %%
analysis
# Out:
#                    Age       Income       AdSpend ClickThroughRate  \
# mean           43.6255  84664.19675    5000.94483         0.154829
# median            43.0      84926.5   5013.440044         0.154505
# mode                64        50268    100.054813         0.010005
# Q1:25th           31.0      51744.5   2523.221165         0.082635
# Q2:50th           43.0      84926.5   5013.440044         0.154505
# Q3:75th           56.0    116815.75   7407.989369         0.228207
# Q4:100th          69.0     149986.0   9997.914781         0.299968
# min                 18        20014    100.054813         0.010005
# max                 69       149986   9997.914781         0.299968
# IQR               25.0     65071.25   4884.768205         0.145572
# 1.5 Rule          37.5    97606.875   7327.152307         0.218358
# Lesser range      -6.5   -45862.375  -4803.931142        -0.135723
# Greater range     93.5   214422.625  14735.141676         0.446565
#
#               ConversionRate WebsiteVisits PagesPerVisit TimeOnSite  \
# mean                0.104389     24.751625      5.549299   7.727718
# median              0.104046          25.0      5.534257   7.682956
# mode                0.010018            25      1.000428   0.501669
# Q1:25th              0.05641          13.0      3.302479    4.06834
# Q2:50th             0.104046          25.0      5.534257   7.682956
# Q3:75th             0.152077          37.0      7.835756  11.481468
# Q4:100th            0.199995          49.0      9.999055  14.995311
# min                 0.010018             0      1.000428   0.501669
# max                 0.199995            49      9.999055  14.995311
# IQR                 0.095667          24.0      4.533277   7.413128
# 1.5 Rule            0.143501          36.0      6.799915  11.119693
# Lesser range       -0.087092         -23.0     -3.497436  -7.051353
# Greater range       0.295578          73.0     14.635671  22.601161
#
#               SocialShares EmailOpens EmailClicks PreviousPurchases  \
# mean              49.79975   9.476875    4.467375            4.4855
# median                50.0        9.0         4.0               4.0
# mode                    61          9           4                 0
# Q1:25th               25.0        5.0         2.0               2.0
# Q2:50th               50.0        9.0         4.0               4.0
# Q3:75th               75.0       14.0         7.0               7.0
# Q4:100th              99.0       19.0         9.0               9.0
# min                      0          0           0                 0
# max                     99         19           9                 9
# IQR                   50.0        9.0         5.0               5.0
# 1.5 Rule              75.0       13.5         7.5               7.5
# Lesser range         -50.0       -8.5        -5.5              -5.5
# Greater range        150.0       27.5        14.5              14.5
#
#               LoyaltyPoints Conversion
# mean              2490.2685     0.8765
# median               2497.0        1.0
# mode                   1392          1
# Q1:25th             1254.75        1.0
# Q2:50th              2497.0        1.0
# Q3:75th             3702.25        1.0
# Q4:100th             4999.0        1.0
# min                       0          0
# max                    4999          1
# IQR                  2447.5        0.0
# 1.5 Rule            3671.25        0.0
# Lesser range        -2416.5        1.0
# Greater range        7373.5        1.0

# %%
# Frequency table

# %%
def freqtable(columnName,pre_dataset):
    freqtable=pd.DataFrame(columns=['unique_values','frequency','relative_frequency','cumsum'])
    freqtable['unique_values']=pre_dataset[columnName].value_counts().index
    freqtable['frequency']=pre_dataset[columnName].value_counts().values
    freqtable['relative_frequency']= freqtable['frequency']/freqtable['frequency'].sum()
    freqtable['cumsum']=freqtable['relative_frequency'].cumsum()
    return freqtable

# %%
# How many customers vistited the website more than 25 times
visits=freqtable('WebsiteVisits',pre_dataset)
sum1=visits[visits['unique_values']>25]['frequency'].sum()
print(sum1)
# Out:
# 3866

# %%
# How many customers clicked the link from the marketing email more than 5 times?
clicks=freqtable('EmailClicks',pre_dataset)
clicks[clicks['unique_values']>5]['frequency'].sum()
# Out:
# np.int64(3142)

# %%
clicks
# Out:
#    unique_values  frequency  relative_frequency    cumsum
# 0              4        844            0.105500  0.105500
# 1              3        828            0.103500  0.209000
# 2              2        821            0.102625  0.311625
# 3              7        810            0.101250  0.412875
# 4              9        794            0.099250  0.512125
# 5              0        794            0.099250  0.611375
# 6              1        791            0.098875  0.710250
# 7              6        787            0.098375  0.808625
# 8              5        780            0.097500  0.906125
# 9              8        751            0.093875  1.000000

# %%
pre_dataset['ClickThroughRate'].skew()
# Out:
# np.float64(0.011066343354481298)

# %%
pre_dataset['ClickThroughRate'].kurtosis()
# Out:
# np.float64(-1.2026601229116485)

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sns.histplot(pre_dataset['ClickThroughRate'], kde=True,line_kws={'color': 'blue'})
# Out:
# <Axes: xlabel='ClickThroughRate', ylabel='Count'>

# %% [markdown]
# #BIVARIATE ANALYSIS

# %%
#Q1 What is the average age comparisons of customers based on conversion, and how is the age distribution of converting customers different from non converting customers

# %%
converted=pre_dataset[pre_dataset['Conversion']==1]['Age']
converted
# Out:
# 0       56
# 1       69
# 2       46
# 3       32
# 4       60
#         ..
# 7987    31
# 7990    43
# 7991    62
# 7997    28
# 7998    19
# Name: Age, Length: 7012, dtype: int64

# %%
not_converted=pre_dataset[pre_dataset['Conversion']==0]['Age']
not_converted
# Out:
# 15      41
# 26      29
# 43      24
# 113     25
# 142     31
#         ..
# 7993    20
# 7994    69
# 7995    21
# 7996    43
# 7999    31
# Name: Age, Length: 988, dtype: int64

# %%
from scipy.stats import ttest_ind

# %%
# Here the mean of Age is compared in between converted and non converted customers using independent- Unpaired t-test
ttest_ind(converted,not_converted)
# Out:
# TtestResult(statistic=np.float64(0.1436318382704728), pvalue=np.float64(0.8857948165454852), df=np.float64(7998.0))

# %% [markdown]
# #Null Hypothesis : There is no significant difference in average age between converting and non converting column
# #Alternate hypothesis : There is significant difference in average age between converting and non converting column
# # since p=0.885 > 0.05
# #we accept null hypothesis

# %%
sns.histplot(data=pre_dataset, x='Age', hue='Conversion',kde=True, palette='muted')
plt.title( 'Age Distribution of converting vs non converting')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#Q2 Display the income distribution of all the customers

# %%
sns.histplot(data=pre_dataset, x='Income', hue='Conversion',kde=True, palette='muted')
plt.title( 'Income Distribution of converting vs non converting')
plt.xlabel('Income')
plt.ylabel('Frequency')
plt.show()

# %%
sns.violinplot(x='Conversion',y='Income', hue='Conversion', data=pre_dataset)
plt.title( 'Income Distribution of converting vs non converting')
plt.xlabel('Conversion')
plt.ylabel('Income')
plt.show()

# %%
#Q3 AdSpend variations between the converted and non converted

# %%
cv=pre_dataset[pre_dataset['Conversion']==1]['AdSpend']

# %%
ncv=pre_dataset[pre_dataset['Conversion']==0]['AdSpend']

# %%
ttest_ind(cv,ncv)
# Out:
# TtestResult(statistic=np.float64(11.23728791862939), pvalue=np.float64(4.414521973000761e-29), df=np.float64(7998.0))

# %% [markdown]
# #Null Hypothesis : There is no significant difference in Adspend between converting and non converting column
# #Alternate hypothesis : There is significant difference in Adspend between converting and non converting column
# # since p=4.41 > 0.05
# #we accept null hypothesis

# %%
#Distribution
sns.violinplot(x='Conversion',y='AdSpend',hue='Conversion', data=pre_dataset)
plt.title( 'AdSpend Distribution of converting vs non converting')
plt.xlabel('Conversion')
plt.ylabel('AdSpend')
plt.legend(title="CampaignType", bbox_to_anchor=(1,1), loc='upper left')
plt.show()

# %%
#Q4 What is the average number of website visits for customer who convert, and how it is compared to non converting customers

# %%
cv2=pre_dataset[pre_dataset['Conversion']==1]['WebsiteVisits']
ncv2=pre_dataset[pre_dataset['Conversion']==0]['WebsiteVisits']
ttest_ind(cv2,ncv2)
# Out:
# TtestResult(statistic=np.float64(7.117864613154411), pvalue=np.float64(1.191011817949675e-12), df=np.float64(7998.0))

# %% [markdown]
# #Null Hypothesis : There is no significant difference in website visits between converting and non converting column
# #Alternate hypothesis : There is significant difference in website visits between converting and non converting column
# since p=1.191 > 0.05
# #we accept null hypothesis

# %%
#Distribution
sns.violinplot(x='Conversion',y='WebsiteVisits', hue='Conversion', data=pre_dataset)
plt.title( 'WebsiteVisits Distribution of converting vs non converting')
plt.xlabel('Conversion')
plt.ylabel('WebsiteVisits')
plt.show()

# %%
sns.boxplot(x='Conversion',y='WebsiteVisits', hue='Conversion', data=pre_dataset)
plt.title( 'WebsiteVisits Distribution of converting vs non converting')
plt.xlabel('Conversion')
plt.ylabel('WebsiteVisits')
plt.show()

# %%
#Q5 What is the average time spent on website by customers who convert, and how does this compare to non converting customers

# %%
cv3=pre_dataset[pre_dataset['Conversion']==1]['TimeOnSite']
ncv3=pre_dataset[pre_dataset['Conversion']==0]['TimeOnSite']
ttest_ind(cv3,ncv3)
# Out:
# TtestResult(statistic=np.float64(11.689717100590915), pvalue=np.float64(2.5838016733746137e-31), df=np.float64(7998.0))

# %% [markdown]
# #Null Hypothesis : There is no significant difference in average time spent between converting and non converting column
# #Alternate hypothesis : There is significant difference in average time spent between converting and non converting column
# since p= 2.583 > 0.05
# #we accept null hypothesis

# %%
sns.boxplot(x='Conversion',y='TimeOnSite', data=pre_dataset, hue='Conversion' )
plt.title( 'TimeOnSite Distribution of converting vs non converting')
plt.xlabel('Conversion')
plt.ylabel('TimeOnSite')
plt.show()

# %%
sns.violinplot(x='Conversion',y='TimeOnSite', hue='Conversion', data=pre_dataset)
plt.title( 'TimeOnSite Distribution of converting vs non converting')
plt.xlabel('Conversion')
plt.ylabel('TimeOnSite')
plt.show()

# %%
#Q6 How does the number of previous purchases correlate with conversion rate

# %%
pre_dataset['PreviousPurchases'].corr(pre_dataset['ConversionRate'])
# Out:
# np.float64(-0.023208926149795944)

# %%
sns.regplot(x=pre_dataset['PreviousPurchases'], y=pre_dataset['ConversionRate'], scatter_kws={"alpha": 0.5}, line_kws={"color": "red"})
# Out:
# <Axes: xlabel='PreviousPurchases', ylabel='ConversionRate'>

# %%
# THERE is Negative correlation b/w previous purchases and conversion rate

# %%
#Q7 PLOT THE CORRELATION AND COVARIANCE B/W QUANTITATIVE COLUMNS

# %%
corr_matrix=pre_dataset[quan].corr()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix,annot=True, vmin=-1, vmax=1,annot_kws={"size": 10})
# Out:
# <Axes: >

# %%
pre_dataset[quan].cov()
# Out:
#                            Age        Income       AdSpend  ClickThroughRate  \
# Age                 222.093011  4.889813e+03 -1.948577e+02          0.014449
# Income             4889.812909  1.412286e+09  3.911963e+05         25.508847
# AdSpend            -194.857744  3.911963e+05  8.054461e+06         -1.977834
# ClickThroughRate      0.014449  2.550885e+01 -1.977834e+00          0.007057
# ConversionRate        0.016379  3.619798e+01 -3.143724e+00         -0.000038
# WebsiteVisits        -0.443322 -1.572267e+03  2.951058e+02         -0.027831
# PagesPerVisit        -0.360593  3.790537e+02 -6.849281e+01          0.000019
# TimeOnSite           -0.819063  3.083320e+03 -5.202484e+01         -0.002916
# SocialShares         -4.104882 -6.839048e+03 -1.727194e+03         -0.032260
# EmailOpens            1.281375 -3.231855e+02  2.676716e+02         -0.002915
# EmailClicks           0.375454  9.168446e+02  8.278537e+00         -0.002598
# PreviousPurchases    -0.306594 -1.294146e+03  1.949175e+01         -0.000094
# LoyaltyPoints       299.309092 -3.857795e+05  8.297414e+03         -2.079223
# Conversion            0.007875  1.727843e+02  1.164190e+02          0.003317
#
#                    ConversionRate  WebsiteVisits  PagesPerVisit   TimeOnSite  \
# Age                      0.016379      -0.443322      -0.360593    -0.819063
# Income                  36.197980   -1572.266666     379.053748  3083.320481
# AdSpend                 -3.143724     295.105755     -68.492814   -52.024842
# ClickThroughRate        -0.000038      -0.027831       0.000019    -0.002916
# ConversionRate           0.003012      -0.009489       0.002688     0.002014
# WebsiteVisits           -0.009489     204.841040      -0.443720    -1.357976
# PagesPerVisit            0.002688      -0.443720       6.798316     0.181407
# TimeOnSite               0.002014      -1.357976       0.181407    17.877829
# SocialShares             0.013819       0.135780       0.594434     0.228338
# EmailOpens               0.002021       0.479379       0.007489    -0.119086
# EmailClicks              0.001053       0.133851      -0.000353     0.025346
# PreviousPurchases       -0.003678       0.567907      -0.122628    -0.079297
# LoyaltyPoints           -0.039096      68.797413     -47.851155   -66.196488
# Conversion               0.001683       0.373622       0.088227     0.180314
#
#                    SocialShares  EmailOpens  EmailClicks  PreviousPurchases  \
# Age                   -4.104882    1.281375     0.375454          -0.306594
# Income             -6839.047607 -323.185473   916.844650       -1294.145540
# AdSpend            -1727.193919  267.671644     8.278537          19.491751
# ClickThroughRate      -0.032260   -0.002915    -0.002598          -0.000094
# ConversionRate         0.013819    0.002021     0.001053          -0.003678
# WebsiteVisits          0.135780    0.479379     0.133851           0.567907
# PagesPerVisit          0.594434    0.007489    -0.000353          -0.122628
# TimeOnSite             0.228338   -0.119086     0.025346          -0.079297
# SocialShares         835.277310   -1.985254     0.265375          -1.054660
# EmailOpens            -1.985254   32.616792     0.022998           0.021980
# EmailClicks            0.265375    0.022998     8.159956           0.010591
# PreviousPurchases     -1.054660    0.021980     0.010591           8.341082
# LoyaltyPoints       -189.016485  -23.176813   -11.586313          49.126784
# Conversion            -0.108869    0.234673     0.121736           0.106223
#
#                    LoyaltyPoints  Conversion
# Age                 2.993091e+02    0.007875
# Income             -3.857795e+05  172.784272
# AdSpend             8.297414e+03  116.419028
# ClickThroughRate   -2.079223e+00    0.003317
# ConversionRate     -3.909574e-02    0.001683
# WebsiteVisits       6.879741e+01    0.373622
# PagesPerVisit      -4.785116e+01    0.088227
# TimeOnSite         -6.619649e+01    0.180314
# SocialShares       -1.890165e+02   -0.108869
# EmailOpens         -2.317681e+01    0.234673
# EmailClicks        -1.158631e+01    0.121736
# PreviousPurchases   4.912678e+01    0.106223
# LoyaltyPoints       2.043548e+06   44.685995
# Conversion          4.468600e+01    0.108261

# %%
#Q8 How does Age correlate with time spent on website

# %% [markdown]
# #From the heatmap we can conclude that age and time spent has NEGATIVE CORRELATION of -0.013

# %%
sns.scatterplot(x=pre_dataset['Age'], y=pre_dataset['TimeOnSite'], hue='Conversion', data=pre_dataset)
plt.legend(title="Conversion", bbox_to_anchor=(1,1), loc='upper left')
plt.xlabel("Age")
plt.ylabel("Time On Site")
plt.title("Age vs Time On Site with Conversion Categories")
plt.show()
